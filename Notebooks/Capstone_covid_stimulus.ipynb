# %%
##Import modules

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
snp_500 = pd.read_csv(r'C:/Users/320080011/OneDrive - Philips/Documents/Python NSS/capstone/Data/SNP_Data_June_16.csv',encoding = "ISO-8859-1")
real_gdp = pd.read_excel(r'C:/Users/320080011/OneDrive - Philips/Documents/Python NSS/capstone/Data/us_real_monthly_gdp.xlsx')
real_hrly_earn = pd.read_excel(r'C:/Users/320080011/OneDrive - Philips/Documents/Python NSS/capstone/Data/Real_hourly_earnings_IR.xlsx')
DTY_curve_rates = pd.read_excel(r'C:/Users/320080011/OneDrive - Philips/Documents/Python NSS/capstone/Data/Daily_Treasury_Yield_Curve_Rates.xlsx')
unemp_rate = pd.read_excel(r'C:/Users/320080011/OneDrive - Philips/Documents/Python NSS/capstone/Data/unemp_rate.xlsx')

# %%
PPP_industry = pd.read_excel(r'C:/Users/320080011/OneDrive - Philips/Documents/Python NSS/capstone/Data/PPP_industry.xlsx')

# %%
PPP_state = pd.read_excel(r'C:/Users/320080011/OneDrive - Philips/Documents/Python NSS/capstone/Data/PPP_state.xlsx')

# %%
##cleaning data

# %%
PPP_state.Date = PPP_state.Date.dt.strftime('%m/%d/%Y')
PPP_state.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448 entries, 0 to 447
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 448 non-null    object
#  1   State                448 non-null    object
#  2   Approved_PPP_Loans   448 non-null    int64
#  3   Approved_PPP_Amount  448 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 14.1+ KB

# %%
PPP_industry.Date = PPP_industry.Date.dt.strftime('%m/%d/%Y')
PPP_industry.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         83 non-null     object
#  1   NAICS Subsector Description  83 non-null     object
#  2   Approved Loans               83 non-null     int64
#  3   Approved Dollars             83 non-null     int64
#  4   % of Amount                  83 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
unemp_rate.Date = unemp_rate.Date.dt.strftime('%m/%d/%Y')
unemp_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               152 non-null    object
#  1   unemployment_rate  152 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 2.5+ KB

# %%
DTY_curve_rates.Date = pd.to_datetime(DTY_curve_rates.Date)
DTY_curve_rates.Date = DTY_curve_rates.Date.dt.strftime('%m/%d/%Y')
DTY_curve_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        107 non-null    object
#  1   1 Mo(DTY)   107 non-null    float64
#  2   2 Mo(DTY)   107 non-null    float64
#  3   3 Mo(DTY)   107 non-null    float64
#  4   6 Mo(DTY)   107 non-null    float64
#  5   1 Yr(DTY)   107 non-null    float64
#  6   2 Yr(DTY)   107 non-null    float64
#  7   3 Yr(DTY)   107 non-null    float64
#  8   5 Yr(DTY)   107 non-null    float64
#  9   7 Yr(DTY)   107 non-null    float64
#  10  10 Yr(DTY)  107 non-null    float64
#  11  20 Yr(DTY)  107 non-null    float64
#  12  30 Yr(DTY)  107 non-null    float64
# dtypes: float64(12), object(1)
# memory usage: 11.0+ KB

# %%
real_hrly_earn.Date = real_hrly_earn.Date.dt.strftime('%m/%d/%Y')
real_hrly_earn
# Out:
#            Date  all_real_avg_hourly_earnings  all_real_avg_weekly_earnings  \
# 0    04/01/2010                        -0.005                         0.005
# 1    05/01/2010                         0.000                         0.800
# 2    06/01/2010                         0.700                         1.900
# 3    07/01/2010                         0.500                         1.400
# 4    08/01/2010                         0.600                         1.800
# ..          ...                           ...                           ...
# 116  12/01/2019                         0.700                         0.100
# 117  01/01/2020                         0.500                         0.000
# 118  02/01/2020                         0.600                         0.700
# 119  03/01/2020                         1.600                         0.600
# 120  04/01/2020                         7.500                         6.900
#
#      CPI_All_Urban_Consumers  \
# ...

# %%
real_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         133 non-null    datetime64[ns]
#  1   Real_GDP(T)  133 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 2.2 KB

# %%
real_gdp.Date = real_gdp.Date.dt.strftime('%m/%d/%Y')
real_gdp
# Out:
#            Date  Real_GDP(T)
# 0    04/01/2020        16.25
# 1    04/02/2020        16.25
# 2    04/03/2020        16.25
# 3    04/04/2020        16.25
# 4    04/05/2020        16.25
# ..          ...          ...
# 128  05/31/2019        19.03
# 129  04/30/2019        19.00
# 130  03/31/2019        18.89
# 131  02/28/2019        18.90
# 132  01/31/2019        19.00
#
# [133 rows x 2 columns]

# %%
snp_500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Effective date    266 non-null    object
#  1   S&P 500 (TR)      254 non-null    float64
#  2   S&P 500 (Net TR)  254 non-null    float64
#  3   S&P 500           266 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 8.4+ KB

# %%
snp_500.columns=['Date', 'S&P 500 (TR)' , 'S&P 500 (Net TR)' , 'S&P 500']
snp_500
# Out:
#           Date  S&P 500 (TR)  S&P 500 (Net TR)  S&P 500
# 0    5/29/2019       5579.51           4959.74  2783.02
# 1    5/30/2019       5591.97           4970.62  2788.86
# 2    5/31/2019       5519.27           4905.71  2752.06
# 3     6/3/2019       5504.05           4892.16  2744.45
# 4     6/4/2019       5622.31           4997.20  2803.27
# ..         ...           ...               ...      ...
# 261  6/10/2020           NaN               NaN  3190.14
# 262  6/11/2020           NaN               NaN  3002.10
# 263  6/12/2020           NaN               NaN  3041.31
# 264  6/15/2020           NaN               NaN  3066.59
# 265  6/16/2020           NaN               NaN  3124.74
#
# [266 rows x 4 columns]

# %%
snp_500.Date = pd.to_datetime(snp_500.Date)
snp_500.Date = snp_500.Date.dt.strftime('%m/%d/%Y')

# %%
snp_500
# Out:
#            Date  S&P 500 (TR)  S&P 500 (Net TR)  S&P 500
# 0    05/29/2019       5579.51           4959.74  2783.02
# 1    05/30/2019       5591.97           4970.62  2788.86
# 2    05/31/2019       5519.27           4905.71  2752.06
# 3    06/03/2019       5504.05           4892.16  2744.45
# 4    06/04/2019       5622.31           4997.20  2803.27
# ..          ...           ...               ...      ...
# 261  06/10/2020           NaN               NaN  3190.14
# 262  06/11/2020           NaN               NaN  3002.10
# 263  06/12/2020           NaN               NaN  3041.31
# 264  06/15/2020           NaN               NaN  3066.59
# 265  06/16/2020           NaN               NaN  3124.74
#
# [266 rows x 4 columns]

# %%
merge_snp_500_UMP = pd.merge(left=snp_500,right=unemp_rate,left_on='Date',right_on='Date',how='outer')
merge_snp_500_UMP
# Out:
#            Date  S&P 500 (TR)  S&P 500 (Net TR)  S&P 500  unemployment_rate
# 0    05/29/2019       5579.51           4959.74  2783.02                NaN
# 1    05/30/2019       5591.97           4970.62  2788.86                NaN
# 2    05/31/2019       5519.27           4905.71  2752.06                NaN
# 3    06/03/2019       5504.05           4892.16  2744.45                NaN
# 4    06/04/2019       5622.31           4997.20  2803.27                NaN
# ..          ...           ...               ...      ...                ...
# 310  05/23/2020           NaN               NaN      NaN               13.3
# 311  05/24/2020           NaN               NaN      NaN               13.3
# 312  05/25/2020           NaN               NaN      NaN               13.3
# 313  05/30/2020           NaN               NaN      NaN               13.3
# 314  05/31/2020           NaN               NaN      NaN               13.3
#
# [315 rows x 5 columns]

# %%
merge_snp_500_UMP_real_Hrly_Earn = pd.merge(left=merge_snp_500_UMP,right=real_hrly_earn,left_on='Date',right_on='Date',how='outer')
merge_snp_500_UMP_real_Hrly_Earn
# Out:
#            Date  S&P 500 (TR)  S&P 500 (Net TR)  S&P 500  unemployment_rate  \
# 0    05/29/2019       5579.51           4959.74  2783.02                NaN
# 1    05/30/2019       5591.97           4970.62  2788.86                NaN
# 2    05/31/2019       5519.27           4905.71  2752.06                NaN
# 3    06/03/2019       5504.05           4892.16  2744.45                NaN
# 4    06/04/2019       5622.31           4997.20  2803.27                NaN
# ..          ...           ...               ...      ...                ...
# 423  04/01/2019           NaN               NaN      NaN                NaN
# 424  05/01/2019           NaN               NaN      NaN                NaN
# 425  06/01/2019           NaN               NaN      NaN                NaN
# 426  09/01/2019           NaN               NaN      NaN                NaN
# 427  12/01/2019           NaN               NaN      NaN                NaN
#
# ...

# %%
merge_snp_500_UMP_real_Hrly_Earn_real_gdp = pd.merge(left=merge_snp_500_UMP_real_Hrly_Earn,right=real_gdp,left_on='Date',right_on='Date',how='outer')
merge_snp_500_UMP_real_Hrly_Earn_real_gdp
# Out:
#            Date  S&P 500 (TR)  S&P 500 (Net TR)  S&P 500  unemployment_rate  \
# 0    05/29/2019       5579.51           4959.74  2783.02                NaN
# 1    05/30/2019       5591.97           4970.62  2788.86                NaN
# 2    05/31/2019       5519.27           4905.71  2752.06                NaN
# 3    06/03/2019       5504.05           4892.16  2744.45                NaN
# 4    06/04/2019       5622.31           4997.20  2803.27                NaN
# ..          ...           ...               ...      ...                ...
# 430  06/30/2019           NaN               NaN      NaN                NaN
# 431  04/30/2019           NaN               NaN      NaN                NaN
# 432  03/31/2019           NaN               NaN      NaN                NaN
# 433  02/28/2019           NaN               NaN      NaN                NaN
# 434  01/31/2019           NaN               NaN      NaN                NaN
#
# ...

# %%
merge_snp_500_UMP_real_Hrly_Earn_real_gdp_DTY_curve_rates = pd.merge(left=merge_snp_500_UMP_real_Hrly_Earn_real_gdp,right=DTY_curve_rates,left_on='Date',right_on='Date',how='outer')
merge_snp_500_UMP_real_Hrly_Earn_real_gdp_DTY_curve_rates
# Out:
#            Date  S&P 500 (TR)  S&P 500 (Net TR)  S&P 500  unemployment_rate  \
# 0    05/29/2019       5579.51           4959.74  2783.02                NaN
# 1    05/30/2019       5591.97           4970.62  2788.86                NaN
# 2    05/31/2019       5519.27           4905.71  2752.06                NaN
# 3    06/03/2019       5504.05           4892.16  2744.45                NaN
# 4    06/04/2019       5622.31           4997.20  2803.27                NaN
# ..          ...           ...               ...      ...                ...
# 430  06/30/2019           NaN               NaN      NaN                NaN
# 431  04/30/2019           NaN               NaN      NaN                NaN
# 432  03/31/2019           NaN               NaN      NaN                NaN
# 433  02/28/2019           NaN               NaN      NaN                NaN
# 434  01/31/2019           NaN               NaN      NaN                NaN
#
# ...

# %%
merged_data = merge_snp_500_UMP_real_Hrly_Earn_real_gdp_DTY_curve_rates

# %%
merged_data = pd.merge(left=merged_data,right=PPP_industry,left_on='Date',right_on='Date',how='outer')
merged_data
# Out:
#            Date  S&P 500 (TR)  S&P 500 (Net TR)  S&P 500  unemployment_rate  \
# 0    05/29/2019       5579.51           4959.74  2783.02                NaN
# 1    05/30/2019       5591.97           4970.62  2788.86                NaN
# 2    05/31/2019       5519.27           4905.71  2752.06                NaN
# 3    06/03/2019       5504.05           4892.16  2744.45                NaN
# 4    06/04/2019       5622.31           4997.20  2803.27                NaN
# ..          ...           ...               ...      ...                ...
# 510  06/06/2020           NaN               NaN      NaN                NaN
# 511  06/06/2020           NaN               NaN      NaN                NaN
# 512  06/06/2020           NaN               NaN      NaN                NaN
# 513  06/06/2020           NaN               NaN      NaN                NaN
# 514  06/06/2020           NaN               NaN      NaN                NaN
#
# ...

# %%
merged_data = pd.merge(left=merged_data,right = PPP_state, left_on='Date', right_on='Date',how='outer')
merged_data
# Out:
#             Date  S&P 500 (TR)  S&P 500 (Net TR)  S&P 500  unemployment_rate  \
# 0     05/29/2019       5579.51           4959.74  2783.02                NaN
# 1     05/30/2019       5591.97           4970.62  2788.86                NaN
# 2     05/31/2019       5519.27           4905.71  2752.06                NaN
# 3     06/03/2019       5504.05           4892.16  2744.45                NaN
# 4     06/04/2019       5622.31           4997.20  2803.27                NaN
# ...          ...           ...               ...      ...                ...
# 5295  06/06/2020           NaN               NaN      NaN                NaN
# 5296  06/06/2020           NaN               NaN      NaN                NaN
# 5297  06/06/2020           NaN               NaN      NaN                NaN
# 5298  06/06/2020           NaN               NaN      NaN                NaN
# 5299  06/06/2020           NaN               NaN      NaN                NaN
#
# ...

# %%
merged_data.to_csv('merged_data1.csv')
